# %%
# import libraries
import pandas as pd
import seaborn as sns
import matplotlib as plt
import numpy as np

# %% [markdown]
# Formatting and Cleaning

# %%
#cleaning
demo = pd.read_csv('base_dfs/df_final_demo.csv')
demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 0        45105.30           6.0            9.0
# 1       110860.30           6.0            9.0
# 2        52467.79           6.0            9.0
# 3        67454.65           3.0            6.0
# 4       103671.75           0.0            3.0
# ...           ...           ...            ...
# 70604  1411062.68           5.0            5.0
# 70605   101867.07           6.0            6.0
# 70606    40745.00           3.0            3.0
# 70607   475114.69           4.0            4.0
# 70608   157498.73           7.0            7.0
#
# [70609 rows x 9 columns]

# %%
# visualize nulls 
demo.isna().sum()
# Out:
# client_id            0
# clnt_tenure_yr      14
# clnt_tenure_mnth    14
# clnt_age            15
# gendr               14
# num_accts           14
# bal                 14
# calls_6_mnth        14
# logons_6_mnth       14
# dtype: int64

# %%
# Rows with null values
demo.loc[demo["clnt_age"].isna()]
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 4164     7402828             NaN               NaN       NaN   NaN        NaN
# 8316      355337             NaN               NaN       NaN   NaN        NaN
# 8677     8412164             NaN               NaN       NaN   NaN        NaN
# 9583     4666211             8.0             106.0       NaN     F        2.0
# 13444    2222915             NaN               NaN       NaN   NaN        NaN
# 18066    4876926             NaN               NaN       NaN   NaN        NaN
# 25961    5277910             NaN               NaN       NaN   NaN        NaN
# 28432    7616759             NaN               NaN       NaN   NaN        NaN
# 35323    8191345             NaN               NaN       NaN   NaN        NaN
# 43518    1227228             NaN               NaN       NaN   NaN        NaN
# 46076    8611797             NaN               NaN       NaN   NaN        NaN
# 47189    5144725             NaN               NaN       NaN   NaN        NaN
# 49846    1037867             NaN               NaN       NaN   NaN        NaN
# 63701    1618749             NaN               NaN       NaN   NaN        NaN
# 66219    6021001             NaN               NaN       NaN   NaN        NaN
#
#             bal  calls_6_mnth  logons_6_mnth
# 4164        NaN           NaN            NaN
# 8316        NaN           NaN            NaN
# 8677        NaN           NaN            NaN
# 9583   42550.55           4.0            7.0
# 13444       NaN           NaN            NaN
# 18066       NaN           NaN            NaN
# 25961       NaN           NaN            NaN
# 28432       NaN           NaN            NaN
# 35323       NaN           NaN            NaN
# 43518       NaN           NaN            NaN
# 46076       NaN           NaN            NaN
# 47189       NaN           NaN            NaN
# 49846       NaN           NaN            NaN
# 63701       NaN           NaN            NaN
# 66219       NaN           NaN            NaN

# %%
# find the client_id that are missing all values
nullRows = demo.loc[demo['bal'].isna()]['client_id'].values

# %%
# drop row with null values
demo.dropna(thresh=7, inplace=True)

# %%
# cleaning column names and fill null value in age, replace X to U (unknown)
demo.rename(columns={'gendr': 'gender'}, inplace=True)
demo.rename(columns= {'clnt_tenure_yr':'tenure_years'}, inplace = True)
demo.rename(columns= {'clnt_tenure_mnth':'tenure_month'}, inplace = True)
demo.rename(columns= {'clnt_age':'age'}, inplace = True)
demo.rename(columns= {'gendr':'gender'}, inplace = True)
demo.rename(columns= {'calls_6_mnth':'calls'}, inplace = True)
demo.rename(columns= {'logons_6_mnth':'logons'}, inplace = True)
demo['age'].fillna(round(demo['age'].mean()), inplace=True)
demo['gender'].replace({'X': 'U'}, inplace=True)

# %%
#cleaning group_type
group_type = pd.read_csv('base_dfs/df_final_experiment_clients.csv')
group_type
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %%
# amount of NaN
group_type.isna().sum()
# Out:
# client_id        0
# Variation    20109
# dtype: int64

# %%
# function to find the index of the client ids that was null in demo
def indexfinder(values, df):
    indexer = []

    for value in values:
        i = df.loc[df['client_id'] == value].index
        indexer.append(i)

    return [x[0] for x in indexer]

list(nullRows)
# Out:
# [7402828,
#  355337,
#  8412164,
#  2222915,
#  4876926,
#  5277910,
#  7616759,
#  8191345,
#  1227228,
#  8611797,
#  5144725,
#  1037867,
#  1618749,
#  6021001]

# %%
# changing name of the column, fill all NaN and droping the client ids with null values of the demo
group_type.rename(columns={'Variation': 'group_type'}, inplace=True)
group_type.drop(indexfinder(nullRows, group_type), inplace=True)
group_type.fillna('Unknow', inplace=True)

# %%
#group_type.head()

# %%
#cleaning data 1
data1 = pd.read_csv('base_dfs\df_final_web_data_pt_1.csv')
data1
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 343136    2443347  465784886_73090545671  136329900_10529659391_316129
# 343137    2443347  465784886_73090545671  136329900_10529659391_316129
# 343138    2443347  465784886_73090545671  136329900_10529659391_316129
# 343139    2443347  465784886_73090545671  136329900_10529659391_316129
# 343140    2443347  465784886_73090545671  136329900_10529659391_316129
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# 1            step_2  2017-04-17 15:26:51
# 2            step_3  2017-04-17 15:19:22
# 3            step_2  2017-04-17 15:19:13
# 4            step_3  2017-04-17 15:18:04
# ...             ...                  ...
# 343136      confirm  2017-03-31 15:15:46
# 343137       step_3  2017-03-31 15:14:53
# 343138       step_2  2017-03-31 15:12:08
# 343139       step_1  2017-03-31 15:11:37
# 343140        start  2017-03-31 15:10:47
#
# [343141 rows x 5 columns]

# %%
#cleaning data 2
data2 = pd.read_csv('base_dfs\df_final_web_data_pt_2.csv')
data2
# Out:
#         client_id             visitor_id                      visit_id  \
# 0          763412  601952081_10457207388  397475557_40440946728_419634
# 1         6019349  442094451_91531546617  154620534_35331068705_522317
# 2         6019349  442094451_91531546617  154620534_35331068705_522317
# 3         6019349  442094451_91531546617  154620534_35331068705_522317
# 4         6019349  442094451_91531546617  154620534_35331068705_522317
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0           confirm  2017-06-06 08:56:00
# 1           confirm  2017-06-01 11:59:27
# 2            step_3  2017-06-01 11:58:48
# 3            step_2  2017-06-01 11:58:08
# 4            step_1  2017-06-01 11:57:58
# ...             ...                  ...
# 412259        start  2017-05-24 18:46:10
# 412260        start  2017-05-24 18:45:29
# 412261       step_1  2017-05-24 18:44:51
# 412262        start  2017-05-24 18:44:34
# 412263        start  2017-06-03 12:17:09
#
# [412264 rows x 5 columns]

# %%
# CONCATENATING THE 2 PARTS OF THE "DIGITAL FOOTPRINTS"
webdata = pd.concat([data1, data2], axis=0).reset_index(drop=True)
webdata.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04

# %%
webdata.dtypes
# Out:
# client_id        int64
# visitor_id      object
# visit_id        object
# process_step    object
# date_time       object
# dtype: object

# %%
# drop duplicates and the client ids with null values on demo
webdata.drop_duplicates(inplace=True)
webdata.drop(indexfinder(nullRows, webdata), inplace=True)

# %%
# formatting date time
webdata['date_time'] = pd.to_datetime(webdata['date_time'])

# %%
# filtering to client ids on demo
unique_client_id= demo["client_id"].to_list()
webdata2 = webdata.loc[webdata["client_id"].isin(unique_client_id)]
webdata2
webdata2['client_id'].nunique()
# Out:
# 70595

# %% [markdown]
# Import to SQL

# %%
# import mysql.connector
# from getpass import getpass
# from sqlalchemy import create_engine

# %%
# # get connected to the sql 

# host= '127.0.0.1'
# pw= getpass()
# user= 'root'

# conn = mysql.connector.connect(host= host, user= user, password= pw)

# %%
#now are creating a cursor, that will hold our query, execute it, and fetch results

# cursor = conn.cursor()

# %%
# # querying the database to sql

# query = """CREATE DATABASE IF NOT EXISTS project;"""

# cursor.execute(query)

# query1 = "SHOW DATABASES"
# cursor.execute(query1)
# cursor.fetchall()

# %%
# #sending to sql
# eng3 = create_engine(f'mysql+pymysql://{user}:{pw}@{host}/project')
# webdata.to_sql('webdata', con= eng3)

# %%
# #sending to sql
# eng2 = create_engine(f'mysql+pymysql://{user}:{pw}@{host}/project')
# group_type.to_sql('group_type', con= eng2)

# %%
# #sending to sql
# eng = create_engine(f'mysql+pymysql://{user}:{pw}@{host}/project')
# demo.to_sql('demo', con= eng)

# %% [markdown]
# DESCRIPTIVE STATS

# %% [markdown]
# FUNCTIONS

# %%
from scipy.stats import chi2_contingency
from scipy.stats.contingency import association

# %%
# filter of diferent group types
gt_test=group_type[group_type["group_type"]=="Test"]
gt_control=group_type[group_type["group_type"]=="Control"]
gt_unknown=group_type[group_type["group_type"]=="Unknow"]

# %%
# function to count the number of successful visits
def count_successful(df_webdata,grouptype):
    
    #filter the df to the grouptype
    grouptype_id=grouptype["client_id"].to_list()
    df_webdata_filter=df_webdata.loc[df_webdata["client_id"].isin(grouptype_id)]

    #create a groupby iterable
    grouped=df_webdata_filter.groupby("visit_id")

    count=0
    timespent_list = []

    for name, group in grouped:  # iterating groupby object
        # print(f"Group name {name}")
        # display(group)
        my_df=pd.DataFrame(group.groupby("process_step").agg({"date_time":"max"}))

        my_dict=my_df.to_dict()

        try:
            if my_dict["date_time"]["confirm"]>my_dict["date_time"]["step_3"]:
                if my_dict["date_time"]["step_3"]>my_dict["date_time"]["step_2"]:
                    if my_dict["date_time"]["step_2"]>my_dict["date_time"]["step_1"]:
                        if my_dict["date_time"]["step_1"]>my_dict["date_time"]["start"]:
                            count+=1
                            time_spent=my_dict["date_time"]["confirm"]-my_dict["date_time"]["start"]
                            timespent_list.append(time_spent)
        
        except:
            pass
    return (len(grouptype_id), df_webdata_filter["visit_id"].nunique(), count, timespent_list,
print("index [0] - Number of client_id's:"), print(len(grouptype_id)),
print("index [1] - Number of visit_id's: "), print(df_webdata_filter["visit_id"].nunique()),
print("index [2] - Number of successful op.: "), print(count), 
print("index [3] - Timespent list: "), print(timespent_list))

# %%
count_control=count_successful(webdata2,gt_control)
count_test=count_successful(webdata2,gt_test)
# Out:
# index [0] - Number of client_id's:
# 23527
# index [1] - Number of visit_id's:
# 32183
# index [2] - Number of successful op.:
# 14006
# index [3] - Timespent list:
# [Timedelta('0 days 00:12:01'), Timedelta('0 days 00:05:41'), Timedelta('0 days 00:04:00'), Timedelta('0 days 00:02:34'), Timedelta('0 days 00:12:56'), Timedelta('0 days 00:01:44'), Timedelta('0 days 00:05:35'), Timedelta('0 days 00:02:24'), Timedelta('0 days 00:07:27'), Timedelta('0 days 00:04:55'), Timedelta('0 days 00:03:00'), Timedelta('0 days 00:07:13'), Timedelta('0 days 00:04:22'), Timedelta('0 days 00:01:18'), Timedelta('0 days 00:02:16'), Timedelta('0 days 00:04:31'), Timedelta('0 days 00:02:52'), Timedelta('0 days 00:02:21'), Timedelta('0 days 00:03:32'), Timedelta('0 days 00:03:36'), Timedelta('0 days 00:02:51'), Timedelta('0 days 00:06:16'), Timedelta('0 days 00:03:01'), Timedelta('0 days 00:03:49'), Timedelta('0 days 00:01:29'), Timedelta('0 days 00:12:14'), Timedelta('0 days 00:06:17'), Timedelta('0 days 00:01:27'), Timedelta('0 days 00:06:46'), Timedelta('0 days 00:11:31'), Timedelta('0 days 00:04:19'), Timedelta('0 days 00:02:09'), Timedelta('0 days 00:10:25'), Timedelta('0 days 00:01:49'), Timedelta('0 days 00:03:45'), Timedelta('0 days 00:02:55'), Timedelta('0 days 00:02:45'), Timedelta('0 days 00:02:39'), Timedelta('0 days 00:05:48'), Timedelta('0 days 00:09:03'), Timedelta('0 days 00:10:42'), Timedelta('0 days 00:05:23'), Timedelta('0 days 00:02:04'), Timedelta('0 days 00:02:09'), Timedelta('0 days 00:02:38'), Timedelta('0 days 00:02:21'), Timedelta('0 days 00:04:01'), Timedelta('0 days 00:02:58'), Timedelta('0 days 00:03:17'), Timedelta('0 days 00:02:11'), Timedelta('0 days 00:02:02'), Timedelta('0 days 00:03:33'), Timedelta('0 days 00:03:46'), Timedelta('0 days 00:15:59'), Timedelta('0 days 00:02:47'), Timedelta('0 days 00:05:21'), Timedelta('0 days 00:03:08'), Timedelta('0 days 00:03:55'), Timedelta('0 days 00:03:15'), Timedelta('0 days 00:01:40'), Timedelta('0 days 00:02:36'), Timedelta('0 days 00:01:40'), Timedelta('0 days 00:06:05'), Timedelta('0 days 00:03:16'), Timedelta('0 days 00:09:39'), Timedelta('0 days 00:03:57'), Timedelta('0 days 00:01:29'), Timedelta('0 days 00:05:57'), Timedelta('0 days 00:04:27'), Timedelta('0 days 00:02:40'), Timedelta('0 days 00:02:45'), Timedelta('0 days 00:14:00'), Timedelta('0 days 00:05:38'), Timedelta('0 days 00:13:53'), Timedelta('0 days 00:03:40'), Timedelta('0 days 00:02:26'), Timedelta('0 days 00:03:09'), Timedelta('0 days 00:04:03'), Timedelta('0 days 00:03:38'), Timedelta('0 days 00:01:07'), Timedelta('0 days 00:02:00'), Timedelta('0 days 00:02:50'), Timedelta('0 days 00:02:04'), Timedelta('0 days 00:13:48'), Timedelta('0 days 00:02:20'), Timedelta('0 days 00:03:45'), Timedelta('0 days 00:01:58'), Timedelta('0 days 00:10:39'), Timedelta('0 days 00:03:58'), Timedelta('0 days 00:02:12'), Timedelta('0 days 00:03:52'), Timedelta('0 days 00:07:57'), Timedelta('0 days 00:13:26'), Timedelta('0 days 00:06:16'), Timedelta('0 days 00:08:38'), Timedelta('0 days 00:01:22'), Timedelta('0 days 00:01:48'), Timedelta('0 days 00:23:06'), Timedelta('0 days 00:05:56'), Timedelta('0 days 00:02:56'), Timedelta('0 days 00:06:07'), Timedelta('0 days 00:07:52'), Timedelta('0 days 00:08:22'), Timedelta('0 days 00:16:21'), Timedelta('0 days 00:05:16'), Timedelta('0 days 00:02:41'), Timedelta('0 days 00:05:52'), Timedelta('0 days 00:04:03'), Timedelta('0 days 00:06:39'), Timedelta('0 days 00:07:04'), Timedelta('0 days 00:04:22'), Timedelta('0 days 00:03:08'), Timedelta('0 days 00:06:28'), Timedelta('0 days 00:04:56'), Timedelta('0 days 00:05:52'), Timedelta('0 days 00:26:07'), Timedelta('0 days 00:05:22'), Timedelta('0 days 00:06:08'), Timedelta('0 days 00:19:42'), Timedelta('0 days 00:06:40'), Timedelta('0 days 00:03:32'), Timedelta('0 days 00:15:54'), Timedelta('0 days 00:04:16'), Timedelta('0 days 00:08:54'), Timedelta('0 days 00:14:14'), Timedelta('0 days 00:04:00'), Timedelta('0 days 00:04:56'), Timedelta('0 days 00:01:36'), Timedelta('0 days 00:05:46'), Timedelta('0 days 00:15:54'), Timedelta('0 days 00:01:19'), Timedelta('0 days 00:04:15'), Timedelta('0 days 00:08:00'), Timedelta ...
# index [0] - Number of client_id's:
# 26961
# index [1] - Number of visit_id's:
# 37122
# index [2] - Number of successful op.:
# 17474
# index [3] - Timespent list:
# [Timedelta('0 days 00:02:59'), Timedelta('0 days 00:03:00'), Timedelta('0 days 00:01:35'), Timedelta('0 days 00:16:57'), Timedelta('0 days 00:05:51'), Timedelta('0 days 00:03:29'), Timedelta('0 days 00:02:14'), Timedelta('0 days 00:07:46'), Timedelta('0 days 00:03:23'), Timedelta('0 days 00:03:41'), Timedelta('0 days 00:04:37'), Timedelta('0 days 00:05:09'), Timedelta('0 days 00:06:12'), Timedelta('0 days 00:05:46'), Timedelta('0 days 00:14:15'), Timedelta('0 days 00:02:38'), Timedelta('0 days 00:01:47'), Timedelta('0 days 00:04:10'), Timedelta('0 days 00:06:11'), Timedelta('0 days 00:02:02'), Timedelta('0 days 00:06:32'), Timedelta('0 days 00:02:47'), Timedelta('0 days 00:03:54'), Timedelta('0 days 00:03:51'), Timedelta('0 days 00:05:10'), Timedelta('0 days 00:04:00'), Timedelta('0 days 00:13:27'), Timedelta('0 days 00:01:55'), Timedelta('0 days 00:00:59'), Timedelta('0 days 00:01:15'), Timedelta('0 days 00:04:39'), Timedelta('0 days 00:03:04'), Timedelta('0 days 00:04:10'), Timedelta('0 days 00:05:25'), Timedelta('0 days 00:11:32'), Timedelta('0 days 00:02:27'), Timedelta('0 days 00:10:42'), Timedelta('0 days 00:02:22'), Timedelta('0 days 00:01:47'), Timedelta('0 days 00:04:32'), Timedelta('0 days 00:24:12'), Timedelta('0 days 00:05:35'), Timedelta('0 days 00:01:35'), Timedelta('0 days 00:02:29'), Timedelta('0 days 00:02:45'), Timedelta('0 days 00:04:29'), Timedelta('0 days 00:07:09'), Timedelta('0 days 00:01:41'), Timedelta('0 days 00:03:38'), Timedelta('0 days 00:01:02'), Timedelta('0 days 00:03:53'), Timedelta('0 days 00:04:15'), Timedelta('0 days 00:03:10'), Timedelta('0 days 00:01:41'), Timedelta('0 days 00:03:08'), Timedelta('0 days 00:06:09'), Timedelta('0 days 00:05:48'), Timedelta('0 days 00:10:02'), Timedelta('0 days 00:04:07'), Timedelta('0 days 00:06:53'), Timedelta('0 days 00:01:47'), Timedelta('0 days 00:07:32'), Timedelta('0 days 00:02:18'), Timedelta('0 days 00:02:41'), Timedelta('0 days 00:01:46'), Timedelta('0 days 00:06:43'), Timedelta('0 days 00:01:31'), Timedelta('0 days 00:02:04'), Timedelta('0 days 00:10:22'), Timedelta('0 days 00:02:50'), Timedelta('0 days 00:06:30'), Timedelta('0 days 00:02:55'), Timedelta('0 days 00:02:34'), Timedelta('0 days 00:00:45'), Timedelta('0 days 00:09:35'), Timedelta('0 days 00:09:42'), Timedelta('0 days 00:03:23'), Timedelta('0 days 00:02:24'), Timedelta('0 days 00:04:11'), Timedelta('0 days 00:16:21'), Timedelta('0 days 00:11:15'), Timedelta('0 days 00:01:59'), Timedelta('0 days 00:02:41'), Timedelta('0 days 00:08:45'), Timedelta('0 days 00:05:06'), Timedelta('0 days 00:01:10'), Timedelta('0 days 00:04:07'), Timedelta('0 days 00:02:22'), Timedelta('0 days 00:19:24'), Timedelta('0 days 00:01:18'), Timedelta('0 days 00:16:26'), Timedelta('0 days 00:03:41'), Timedelta('0 days 00:07:42'), Timedelta('0 days 00:01:40'), Timedelta('0 days 00:00:47'), Timedelta('0 days 00:01:50'), Timedelta('0 days 00:04:48'), Timedelta('0 days 00:03:04'), Timedelta('0 days 00:02:40'), Timedelta('0 days 00:05:12'), Timedelta('0 days 00:03:13'), Timedelta('0 days 00:02:32'), Timedelta('0 days 00:02:22'), Timedelta('0 days 00:03:08'), Timedelta('0 days 00:05:37'), Timedelta('0 days 00:04:10'), Timedelta('0 days 00:03:03'), Timedelta('0 days 00:07:25'), Timedelta('0 days 00:03:29'), Timedelta('0 days 00:40:56'), Timedelta('0 days 00:02:37'), Timedelta('0 days 00:03:03'), Timedelta('0 days 00:03:09'), Timedelta('0 days 00:04:59'), Timedelta('0 days 00:13:46'), Timedelta('0 days 00:02:25'), Timedelta('0 days 00:02:24'), Timedelta('0 days 00:12:02'), Timedelta('0 days 00:02:21'), Timedelta('0 days 00:04:39'), Timedelta('0 days 00:03:06'), Timedelta('0 days 00:02:03'), Timedelta('0 days 00:03:03'), Timedelta('0 days 00:02:26'), Timedelta('0 days 00:05:29'), Timedelta('0 days 00:05:35'), Timedelta('0 days 00:02:23'), Timedelta('0 days 00:04:57'), Timedelta('0 days 00:05:38'), Timedelta('0 days 00:01:56'), Timedelta('0 days 00:02:10'), Timedelta('0 days 00:08:08'), Timedelta('0 days 00:01:48'), Timedelta ...

# %%
# function to count the number of unsuccessful regarding the timestamp
def count_error_timestamps(df_webdata,grouptype):
    
    #filter the df to the grouptype
    grouptype_id=grouptype["client_id"].to_list()
    df_webdata_filter=df_webdata.loc[df_webdata["client_id"].isin(grouptype_id)]

    #create a groupby iterable
    grouped=df_webdata_filter.groupby("visit_id")

    count=0
   
    for name, group in grouped:  # iterating groupby object
        # print(f"Group name {name}")
        # display(group)
        my_df=pd.DataFrame(group.groupby("process_step").agg({"date_time":"max"}))

        my_dict=my_df.to_dict()
        
        
        try: # we could have used "or" instead of "elif"
            if my_dict["date_time"]["confirm"] < my_dict["date_time"]["step_3"]:
                count+=1            
            elif my_dict["date_time"]["step_3"] < my_dict["date_time"]["step_2"]:
                count+=1                
            elif my_dict["date_time"]["step_2"] < my_dict["date_time"]["step_1"]:
                count+=1                
            elif my_dict["date_time"]["step_1"] < my_dict["date_time"]["start"]:
                count+=1
        except:
            pass
    return (len(grouptype_id), df_webdata_filter["visit_id"].nunique(), count, print(f"""index [0] - Number of client_id's:{len(grouptype_id)}
index [1] - Number of visit_id's: {df_webdata_filter["visit_id"].nunique()}
index [2] - Number of error timestamps op.: {count}"""))

# %%
error_timestamps=count_error_timestamps(webdata2,gt_control)
error_timestamps=count_error_timestamps(webdata2,gt_test)
# Out:
# index [0] - Number of client_id's:23527
# index [1] - Number of visit_id's: 32183
# index [2] - Number of error timestamps op.: 595
# index [0] - Number of client_id's:26961
# index [1] - Number of visit_id's: 37122
# index [2] - Number of error timestamps op.: 326

# %%
# function to count the number of visits that return to "start"
def return_to_start(df_webdata,grouptype):
    
    #filter the df to the grouptype
    grouptype_id=grouptype["client_id"].to_list()
    df_webdata_filter=df_webdata.loc[df_webdata["client_id"].isin(grouptype_id)]

    #create a groupby iterable
    grouped=df_webdata_filter.groupby("visit_id")

    count=0
   
    for name, group in grouped:  # iterating groupby object
        # print(f"Group name {name}")
        # display(group)
        max_start_0 = pd.DataFrame(group.groupby("process_step").agg({"date_time":"max"})).reset_index()
        max_start_1=max_start_0[max_start_0["process_step"]=="start"]#["date_time"]
        max_start_1=max_start_1[max_start_1["process_step"]=="start"].reset_index(drop=True).drop(columns="process_step")


        my_df=pd.DataFrame(group.groupby("process_step").agg({"date_time":"min"}))

        my_dict=my_df.to_dict()
        
        
        try: # we could have used "or" instead of "elif"
            if pd.Series(my_dict["date_time"]["confirm"])[0] < max_start_1["date_time"][0]:
                count+=1            
            elif pd.Series(my_dict["date_time"]["step_3"])[0] < max_start_1["date_time"][0]:
                count+=1                
            elif pd.Series(my_dict["date_time"]["step_2"])[0] < max_start_1["date_time"][0]:
                count+=1                
            elif pd.Series(my_dict["date_time"]["step_1"])[0] < max_start_1["date_time"][0]:
                count+=1
        except:
            pass
    return (len(grouptype_id), df_webdata_filter["visit_id"].nunique(),count,
print("index [0] - Number of client_id's: "), print(len(grouptype_id)),
print("index [1] - Number of visit_id's: "), print(df_webdata_filter["visit_id"].nunique()),
print("index [2] - Number of error return to 'start' op.: "), print(count))

# %%
error_start_control = return_to_start(webdata2,gt_control)
error_start_test = return_to_start(webdata2,gt_test)
# Out:
# index [0] - Number of client_id's:
# 23527
# index [1] - Number of visit_id's:
# 32183
# index [2] - Number of error return to 'start' op.:
# 1660
# index [0] - Number of client_id's:
# 26961
# index [1] - Number of visit_id's:
# 37122
# index [2] - Number of error return to 'start' op.:
# 3168

# %% [markdown]
# INFERENTIAL STATS

# %%
my_dict = {"Title":["complete","not complete"], "Control": [count_control[2],count_control[1]-count_control[2]], "Test": [count_test[2],count_test[1]-count_test[2]]}

# %%
my_df =pd.DataFrame(my_dict)
my_df.set_index("Title")
# Out:
#               Control   Test
# Title
# complete        14006  17474
# not complete    18177  19648

# %%
my_df.set_index("Title", inplace = True)

# %%
my_df
# Out:
#               Control   Test
# Title
# complete        14006  17474
# not complete    18177  19648

# %%
chi2_contingency(my_df)
# there is a significance association between complete/non complete and the type of test (control,teste)
# completar o processo é depente do grupo em que se encontra
# Out:
# Chi2ContingencyResult(statistic=87.58546753265996, pvalue=8.071551885934096e-21, dof=1, expected_freq=array([[14618.29362961, 16861.70637039],
#        [17564.70637039, 20260.29362961]]))

# %%
association(my_df, method="cramer")
# Out:
# 0.03557857362311297

# %%
my_df.T.plot(kind = "bar", stacked= True)
# Out:
# <Axes: >
